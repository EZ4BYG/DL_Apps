# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']

# %% [markdown]
# 说明：上采样有多种实现方式，本文使用的是“**反卷积**”来实现的。
# - 下采样实现方式：1. maxpool；2. avgpool；3. 卷积时跨步大于1；—— 图像缩小/像素点减少
# - 上采样实现方式：1. 插值法；2. 反池化（）；3. 反卷积/转置卷积；—— 图像增大/像素点增多
# ![%E5%8F%8D%E6%B1%A0%E5%8C%96.png](attachment:%E5%8F%8D%E6%B1%A0%E5%8C%96.png)
#
# 下采样和上采样的主要区别：
# - 下采样是不断把图像中的尺寸信息，提取到通道数上；
# - 上采样是不断把通道数上的信息恢复到尺寸上。
