# %%
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
N = 500 # 一共500个观测数据
ws = np.random.random(500) * 6    # 速度：s = speed；范围：[0,6]
wd = np.random.random(500) * 360  # 方向：d = direction；范围：[0,360]

# %%
ax = WindroseAxes.from_ax()
ax.bar(wd, ws, normed=True, opening=0.8, edgecolor='white')
ax.set_legend()

# %%
w = np.random.random(10)

# %%
w
# Out:
# array([0.83300582, 0.58743257, 0.5160986 , 0.00873069, 0.62017353,
#        0.04748272, 0.50602685, 0.40213964, 0.13286453, 0.94050299])
