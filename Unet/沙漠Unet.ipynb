# %%
import tensorflow as tf
import numpy as np
import glob 
import os
import matplotlib.pyplot as plt
import matplotlib
import scipy

# %%
gpus = tf.config.experimental.list_physical_devices( device_type = 'GPU' )
# 设置该程序可见的GPU：写到最前面！
tf.config.experimental.set_visible_devices( devices = gpus[5:7], device_type = 'GPU' )

# %% [markdown]
# ### 1. 导入所有文件的路径：

# %%
# 所有训练图片的地址：
image_path = glob.glob( '/home/gaoboyu/学习数据集/沙漠数据集4_100/图像/*' )
label_path = glob.glob( '/home/gaoboyu/学习数据集/沙漠数据集4_100/处理后标签/*' )

# %%
image_count = len(image_path)
len(image_path), len(label_path)
# Out:
# (100, 100)

# %%
# 查看是否对应：
image_path[21:23], label_path[21:23]
# Out:
# (['/home/gaoboyu/学习数据集/沙漠数据集4_100/图像/subimg_28.png',
#   '/home/gaoboyu/学习数据集/沙漠数据集4_100/图像/subimg_29.png'],
#  ['/home/gaoboyu/学习数据集/沙漠数据集4_100/处理后标签/subimg_28.png',
#   '/home/gaoboyu/学习数据集/沙漠数据集4_100/处理后标签/subimg_29.png'])

# %%
# 训练数据的乱序：
index = np.random.permutation( image_count )
image_path = np.array(image_path)[index]
label_path = np.array(label_path)[index]

# %% [markdown]
# ### 2. 创建数据集：

# %%
dataset = tf.data.Dataset.from_tensor_slices( (image_path, label_path) )

# %%
# 划分训练、测试集
val_count = int( image_count*0.2 )
train_count = image_count - val_count

train_dataset = dataset.skip(val_count)  # 跳过前这么多数据
val_dataset = dataset.take(val_count)   # 取前面这么多数据

# %%
# 查看：
train_dataset, val_dataset
# Out:
# (<SkipDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  <TakeDataset shapes: ((), ()), types: (tf.string, tf.string)>)

# %% [markdown]
# ### 3. 预处理函数：

# %%
# 读取图片：3通道
def read_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels = 3)
    return img

# %%
# 读取标签：1通道（每个像素都是标签值）
def read_label(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels = 1)
    return img

# %%
# 对训练数据及标签：随机翻转 —— 训练数据专用！
def random_flip(img, label):
    img_label = tf.concat( [img, label], axis = -1 )  # 图像与标签合并
    img_label = tf.image.resize(img_label, [256,256])
    img_label = tf.image.random_flip_left_right(img_label)  # 随机左右翻转
    img_label = tf.image.random_flip_up_down(img_label)     # 随机上下翻转
    return img_label[:,:,0:3], img_label[:,:,3:]

# %%
# 所有图像归一化 + 标签转数据类型：
def normal(img, label):
    img = tf.cast(img, tf.float32) / 127.5 - 1
    label = tf.cast(label, tf.int32)  # 不能减1，因为里面本身就有0的标签！ 
    return img, label

# %%
# 训练数据加载：需要裁减！
def load_train_image(img_path, label_path):
    # 获取图片与标签：
    img = read_image(img_path)
    label = read_label(label_path)
    # 预处理：随机翻转 —— 自带统一形状！
    img, label = random_flip(img, label)
    # 返回归一化：
    return normal(img, label)

def load_val_image(img_path, label_path):
    # 获取图片与标签：
    img = read_image(img_path)
    label = read_label(label_path)
    # 统一形状：
    img = tf.image.resize(img, [256,256])
    label = tf.image.resize(label, [256,256])
    # 返回归一化：
    return normal(img, label)

# %%
# 将数据应用于函数：
AUTOTUNE = tf.data.experimental.AUTOTUNE   # 多线程加载：图像加载是cpu处理的，cpu可以做多线程！

train_dataset = train_dataset.map( load_train_image, num_parallel_calls = AUTOTUNE )
val_dataset = val_dataset.map( load_val_image, num_parallel_calls = AUTOTUNE )

# %%
train_dataset, val_dataset
# Out:
# (<ParallelMapDataset shapes: ((256, 256, 3), (256, 256, 1)), types: (tf.float32, tf.int32)>,
#  <ParallelMapDataset shapes: ((256, 256, 3), (256, 256, 1)), types: (tf.float32, tf.int32)>)

# %%
# 乱序、划分数据集：
# cashe()：新操作，文件不断放到缓存中，加速！
# prefetch()：新操作，GPU内存不等待，不断预处理图片
BATCH_SIZE = 10
train_dataset = train_dataset.cache().shuffle(train_count).repeat().batch(BATCH_SIZE).prefetch(AUTOTUNE)
val_dataset = val_dataset.cache().batch(BATCH_SIZE)

# %%
train_dataset, val_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>,
#  <BatchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>)

# %%
# 画图最后查看一下：从tf.data.Dataset拿出的数据，都是Tensor的！而matplotlib中的绘图必须是array的！
# 不能放在这里，现在train_dataset里面都是地址！
for image, label in train_dataset.take(1):
    plt.subplot(1,2,1) 
    plt.imshow( (image[0].numpy() + 1)/2 )  # 从[-1,1]转到[0,1]
    plt.subplot(1,2,2)
    plt.imshow( label[0].numpy().reshape(256,256) )

# %% [markdown]
# ### 4. 自定义网络搭建：

# %%
# 以后把模型的自定义，都写到一个函数里 正规！—— 没有输入数据，返回一个模型！—— 层的生成，完全可以用循环！
def create_model():
    inputs = tf.keras.layers.Input( shape = (256,256,3) )  # 所有的层都是大写的！所有这也是一个层！
    
    # 前半部分卷积基自定义：顺序连接 + 用名字获得某层输出
    # 第一部分：_1
    conv2d_1_1 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_1_1' )(inputs)
    bn_1_1 = tf.keras.layers.BatchNormalization( name = 'bn_1_1' )(conv2d_1_1)
    conv2d_1_2 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_1_2' )(bn_1_1)
    bn_1_2 = tf.keras.layers.BatchNormalization( name = 'bn_1_2' )(conv2d_1_2)  # 256 x 256 x 64 √
    maxpool_1_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_1_1' )(bn_1_2)  # 128 x 128 x 64
    
    # 第二部分：_2
    conv2d_2_1 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_2_1' )(maxpool_1_1)
    bn_2_1 = tf.keras.layers.BatchNormalization( name = 'bn_2_1' )(conv2d_2_1)
    conv2d_2_2 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_2_2' )(bn_2_1)
    bn_2_2 = tf.keras.layers.BatchNormalization( name = 'bn_2_2' )(conv2d_2_2)  # 128 x 128 x 128 √
    maxpool_2_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_2_1' )(bn_2_2)  # 64 x 64 x 128
    
    # 第三部分：_3
    conv2d_3_1 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_3_1' )(maxpool_2_1)
    bn_3_1 = tf.keras.layers.BatchNormalization( name = 'bn_3_1' )(conv2d_3_1)
    conv2d_3_2 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_3_2' )(bn_3_1)
    bn_3_2 = tf.keras.layers.BatchNormalization( name = 'bn_3_2' )(conv2d_3_2)  # 64 x 64 x 256 √
    maxpool_3_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_3_1' )(bn_3_2)  # 32 x 32 x 256
    
    # 第四部分：_4
    conv2d_4_1 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_4_1' )(maxpool_3_1)
    bn_4_1 = tf.keras.layers.BatchNormalization( name = 'bn_4_1' )(conv2d_4_1)
    conv2d_4_2 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_4_2' )(bn_4_1)
    bn_4_2 = tf.keras.layers.BatchNormalization( name = 'bn_4_2' )(conv2d_4_2)  # 32 x 32 x 512 √
    maxpool_4_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_4_1' )(bn_4_2)  # 16 x 16 x 512  
    
    # 第五部分：_5 —— 最后没下采样！
    conv2d_5_1 = tf.keras.layers.Conv2D( 1024, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_5_1' )(maxpool_4_1)
    bn_5_1 = tf.keras.layers.BatchNormalization( name = 'bn_5_1' )(conv2d_5_1)
    conv2d_5_2 = tf.keras.layers.Conv2D( 1024, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_5_2' )(bn_5_1)
    bn_5_2 = tf.keras.layers.BatchNormalization( name = 'bn_5_2' )(conv2d_5_2)  # 16 x 16 x 1024
    
    
    # 后半部分自定义：反卷积 + 跳接（带√的）
    
    # 第一部分：x1、x2
    # 上采样：上采用的卷积核是(2,2)
    x1 = tf.keras.layers.Conv2DTranspose( 512, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x1')(bn_5_2)
    bn_x1 = tf.keras.layers.BatchNormalization( name = 'bn_x1' )(x1)  # 32 x 32 x 512
    # 跳接合并：当成一个层！
    x2 = tf.concat( [bn_x1, bn_4_2], axis = -1 )  # 32 x 32 x (512+512) = 32 x 32 x 1024
    conv2d_x2_1 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x2_1' )(x2)
    bn_x2_1 = tf.keras.layers.BatchNormalization( name = 'bn_x2_1' )(conv2d_x2_1)
    conv2d_x2_2 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x2_2' )(bn_x2_1)
    bn_x2_2 = tf.keras.layers.BatchNormalization( name = 'bn_x2_2' )(conv2d_x2_2)  # 32 x 32 x 512
    
    # 第二部分：x3、x4
    # 上采样：上采用的卷积核是(2,2)
    x3 = tf.keras.layers.Conv2DTranspose( 256, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x3')(bn_x2_2)
    bn_x3 = tf.keras.layers.BatchNormalization( name = 'bn_x3' )(x3)  # 64 x 64 x 256
    # 跳接合并：当成一个层！
    x4 = tf.concat( [bn_x3, bn_3_2], axis = -1 )  # 64 x 64 x (256+256) = 64 x 64 x 512
    conv2d_x4_1 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x4_1' )(x4)
    bn_x4_1 = tf.keras.layers.BatchNormalization( name = 'bn_x4_1' )(conv2d_x4_1)
    conv2d_x4_2 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x4_2' )(bn_x4_1)
    bn_x4_2 = tf.keras.layers.BatchNormalization( name = 'bn_x4_2' )(conv2d_x4_2)  # 64 x 64 x 256
    
    # 第三部分：x5、x6
    # 上采样：上采用的卷积核是(2,2)
    x5 = tf.keras.layers.Conv2DTranspose( 128, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x5')(bn_x4_2)
    bn_x5 = tf.keras.layers.BatchNormalization( name = 'bn_x5' )(x5)  # 128 x 128 x 128
    # 跳接合并：当成一个层！
    x6 = tf.concat( [bn_x5, bn_2_2], axis = -1 )  # 128 x 128 x (128+128) = 128 x 128 x 256
    conv2d_x6_1 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x6_1' )(x6)
    bn_x6_1 = tf.keras.layers.BatchNormalization( name = 'bn_x6_1' )(conv2d_x6_1)
    conv2d_x6_2 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x6_2' )(bn_x6_1)
    bn_x6_2 = tf.keras.layers.BatchNormalization( name = 'bn_x6_2' )(conv2d_x6_2)  # 128 x 128 x 128
    
    # 第四部分：x7、x8
    # 上采样：上采用的卷积核是(2,2)
    x7 = tf.keras.layers.Conv2DTranspose( 64, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x7' )(bn_x6_2)
    bn_x7 = tf.keras.layers.BatchNormalization( name = 'bn_x7' )(x7)  # 256 x 256 x 64
    # 跳接合并：当成一个层！
    x8 = tf.concat( [bn_x7, bn_1_2], axis = -1 )  # 256 x 256 x (64+64) = 256 x 256 x 128
    conv2d_x8_1 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x8_1' )(x8)
    bn_x8_1 = tf.keras.layers.BatchNormalization( name = 'bn_x8_1' )(conv2d_x8_1)
    conv2d_x8_2 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x8_2' )(bn_x8_1)
    bn_x8_2 = tf.keras.layers.BatchNormalization( name = 'bn_x8_2' )(conv2d_x8_2)  # 256 x 256 x 64
    
    # 最后的通道数变为34：卷积核为(1,1)；激活函数用softmax
    # 最后输出大小：256 x 256 x 2
    output = tf.keras.layers.Conv2D(2, kernel_size = (1,1), strides = (1,1), padding = 'same', activation = 'softmax', name = 'output')(bn_x8_2)
    
    # 模型搭建：
    model = tf.keras.Model( inputs = inputs, outputs = output )
    return model

# %%
model = create_model()

# %%
# 模型编译
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# %%
# 定义保存模型的回调函数：保存整个模型、只保存最好的！
# 设置保存的路径：
checkpoint_path = '/home/gaoboyu/学习保存的模型/沙漠4'
# 设置回调函数保存模型：没设置的参数都默认
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path,
    monitor = 'val_acc',
    save_best_only = True  # 监控的目标：如果新的epoch结果比前一个要好，那就重新保存最新的，删掉旧的！
)

# %%
train_count, val_count
# Out:
# (80, 20)

# %%
# 模型训练
EPOCHES = 100
history = model.fit(
    train_dataset,
    epochs = EPOCHES,
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8813 - acc: 0.5380WARNING:tensorflow:From /usr/local/Anaconda33/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠4/assets
# 8/8 [==============================] - 16s 2s/step - loss: 0.8813 - acc: 0.5380 - val_loss: 0.6119 - val_acc: 0.8708
# Epoch 2/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.6566 - acc: 0.6391 - val_loss: 1.3289 - val_acc: 0.8533
# Epoch 3/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.6047 - acc: 0.7668 - val_loss: 1.9629 - val_acc: 0.8678
# Epoch 4/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.5678 - acc: 0.8468 - val_loss: 1.7724 - val_acc: 0.8689
# Epoch 5/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.5375 - acc: 0.8599 - val_loss: 1.4186 - val_acc: 0.8708
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5097 - acc: 0.8644INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠4/assets
# 8/8 [==============================] - 16s 2s/step - loss: 0.5097 - acc: 0.8644 - val_loss: 1.5725 - val_acc: 0.8713
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4852 - acc: 0.8676INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠4/assets
# 8/8 [==============================] - 16s 2s/step - loss: 0.4852 - acc: 0.8676 - val_loss: 1.0958 - val_acc: 0.8716
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4633 - acc: 0.8691INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠4/assets
# 8/8 [==============================] - 16s 2s/step - loss: 0.4633 - acc: 0.8691 - val_loss: 0.6225 - val_acc: 0.8718
# Epoch 9/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.4459 - acc: 0.8694 - val_loss: 0.5559 - val_acc: 0.8718
# Epoch 10/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.4295 - acc: 0.8690 - val_loss: 0.5134 - val_acc: 0.8718
# Epoch 11/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.4175 - acc: 0.8687 - val_loss: 0.5497 - val_acc: 0.8718
# Epoch 12/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.4068 - acc: 0.8695 - val_loss: 0.5532 - val_acc: 0.8718
# Epoch 13/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3998 - acc: 0.8690 - val_loss: 0.5127 - val_acc: 0.8718
# Epoch 14/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3936 - acc: 0.8693 - val_loss: 0.3878 - val_acc: 0.8718
# Epoch 15/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3901 - acc: 0.8691 - val_loss: 0.3861 - val_acc: 0.8718
# Epoch 16/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3858 - acc: 0.8694 - val_loss: 0.3898 - val_acc: 0.8718
# Epoch 17/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3840 - acc: 0.8697 - val_loss: 0.5226 - val_acc: 0.8718
# Epoch 18/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3846 - acc: 0.8692 - val_loss: 0.8825 - val_acc: 0.8718
# Epoch 19/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3854 - acc: 0.8693 - val_loss: 1.8963 - val_acc: 0.8718
# Epoch 20/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3838 - acc: 0.8693 - val_loss: 1.5168 - val_acc: 0.8706
# Epoch 21/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3827 - acc: 0.8695 - val_loss: 0.5472 - val_acc: 0.8718
# Epoch 22/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3814 - acc: 0.8699 - val_loss: 0.4471 - val_acc: 0.8677
# Epoch 23/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3800 - acc: 0.8701 - val_loss: 0.4472 - val_acc: 0.8718
# Epoch 24/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3792 - acc: 0.8700 - val_loss: 0.3957 - val_acc: 0.8718
# Epoch 25/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3790 - acc: 0.8698 - val_loss: 0.4113 - val_acc: 0.8718
# Epoch 26/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3803 - acc: 0.8696 - val_loss: 0.4320 - val_acc: 0.8718
# Epoch 27/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3802 - acc: 0.8697 - val_loss: 0.3860 - val_acc: 0.8718
# Epoch 28/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3788 - acc: 0.8710 - val_loss: 0.3937 - val_acc: 0.8718
# Epoch 29/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3795 - acc: 0.8698 - val_loss: 0.3856 - val_acc: 0.8718
# Epoch 30/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3773 - acc: 0.8699 - val_loss: 0.3842 - val_acc: 0.8718
# Epoch 31/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3789 - acc: 0.8706 - val_loss: 0.3870 - val_acc: 0.8718
# Epoch 32/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3787 - acc: 0.8706 - val_loss: 0.4313 - val_acc: 0.8718
# Epoch 33/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3791 - acc: 0.8700 - val_loss: 0.4045 - val_acc: 0.8718
# Epoch 34/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3777 - acc: 0.8699 - val_loss: 0.4825 - val_acc: 0.8718
# Epoch 35/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3803 - acc: 0.8693 - val_loss: 0.4214 - val_acc: 0.8718
# Epoch 36/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3768 - acc: 0.8708 - val_loss: 0.4007 - val_acc: 0.8718
# Epoch 37/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3750 - acc: 0.8714 - val_loss: 0.4157 - val_acc: 0.8718
# Epoch 38/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3745 - acc: 0.8713 - val_loss: 0.3866 - val_acc: 0.8718
# Epoch 39/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3766 - acc: 0.8692 - val_loss: 0.3878 - val_acc: 0.8718
# Epoch 40/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3752 - acc: 0.8699 - val_loss: 0.3951 - val_acc: 0.8718
# Epoch 41/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3749 - acc: 0.8704 - val_loss: 0.3853 - val_acc: 0.8718
# Epoch 42/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3717 - acc: 0.8712 - val_loss: 0.4021 - val_acc: 0.8718
# Epoch 43/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3698 - acc: 0.8716 - val_loss: 0.3982 - val_acc: 0.8718
# Epoch 44/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3730 - acc: 0.8696 - val_loss: 0.4058 - val_acc: 0.8718
# Epoch 45/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3679 - acc: 0.8710 - val_loss: 0.3983 - val_acc: 0.8718
# Epoch 46/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3688 - acc: 0.8708 - val_loss: 0.4178 - val_acc: 0.8717
# Epoch 47/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3708 - acc: 0.8706 - val_loss: 0.3966 - val_acc: 0.8718
# Epoch 48/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3679 - acc: 0.8712 - val_loss: 0.4346 - val_acc: 0.8718
# Epoch 49/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3636 - acc: 0.8703 - val_loss: 0.4063 - val_acc: 0.8710
# Epoch 50/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3607 - acc: 0.8711 - val_loss: 0.4164 - val_acc: 0.8682
# Epoch 51/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3484 - acc: 0.8722 - val_loss: 0.5958 - val_acc: 0.7172
# Epoch 52/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3415 - acc: 0.8727 - val_loss: 0.6188 - val_acc: 0.7915
# Epoch 53/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3360 - acc: 0.8732 - val_loss: 0.6658 - val_acc: 0.7311
# Epoch 54/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3215 - acc: 0.8761 - val_loss: 1.2650 - val_acc: 0.7009
# Epoch 55/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.3073 - acc: 0.8799 - val_loss: 0.8282 - val_acc: 0.7516
# Epoch 56/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2979 - acc: 0.8818 - val_loss: 1.5689 - val_acc: 0.5872
# Epoch 57/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2798 - acc: 0.8882 - val_loss: 1.7857 - val_acc: 0.6490
# Epoch 58/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2663 - acc: 0.8916 - val_loss: 1.5891 - val_acc: 0.6583
# Epoch 59/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2552 - acc: 0.8958 - val_loss: 2.5891 - val_acc: 0.6349
# Epoch 60/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2472 - acc: 0.8980 - val_loss: 2.0269 - val_acc: 0.6715
# Epoch 61/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2429 - acc: 0.8981 - val_loss: 3.6151 - val_acc: 0.5656
# Epoch 62/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.2195 - acc: 0.9093 - val_loss: 2.1293 - val_acc: 0.6673
# Epoch 63/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1956 - acc: 0.9196 - val_loss: 2.6923 - val_acc: 0.6030
# Epoch 64/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1858 - acc: 0.9234 - val_loss: 1.3582 - val_acc: 0.7473
# Epoch 65/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1762 - acc: 0.9270 - val_loss: 1.7828 - val_acc: 0.7046
# Epoch 66/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1737 - acc: 0.9273 - val_loss: 1.4294 - val_acc: 0.7332
# Epoch 67/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1633 - acc: 0.9321 - val_loss: 1.3777 - val_acc: 0.7312
# Epoch 68/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1546 - acc: 0.9353 - val_loss: 1.1674 - val_acc: 0.7688
# Epoch 69/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1506 - acc: 0.9367 - val_loss: 1.4848 - val_acc: 0.7365
# Epoch 70/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1433 - acc: 0.9409 - val_loss: 1.4866 - val_acc: 0.7309
# Epoch 71/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1331 - acc: 0.9450 - val_loss: 1.8691 - val_acc: 0.6897
# Epoch 72/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1240 - acc: 0.9487 - val_loss: 1.1078 - val_acc: 0.7775
# Epoch 73/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1184 - acc: 0.9511 - val_loss: 1.3419 - val_acc: 0.7382
# Epoch 74/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1121 - acc: 0.9537 - val_loss: 1.2161 - val_acc: 0.7632
# Epoch 75/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1109 - acc: 0.9539 - val_loss: 1.0342 - val_acc: 0.7793
# Epoch 76/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1277 - acc: 0.9455 - val_loss: 1.2263 - val_acc: 0.7316
# Epoch 77/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1483 - acc: 0.9340 - val_loss: 1.0841 - val_acc: 0.7638
# Epoch 78/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1354 - acc: 0.9411 - val_loss: 1.3387 - val_acc: 0.7311
# Epoch 79/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1221 - acc: 0.9468 - val_loss: 1.3499 - val_acc: 0.7547
# Epoch 80/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.1010 - acc: 0.9574 - val_loss: 1.6172 - val_acc: 0.7236
# Epoch 81/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0943 - acc: 0.9607 - val_loss: 1.5129 - val_acc: 0.7334
# Epoch 82/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0876 - acc: 0.9636 - val_loss: 1.1452 - val_acc: 0.7719
# Epoch 83/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0809 - acc: 0.9666 - val_loss: 1.1534 - val_acc: 0.7664
# Epoch 84/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0747 - acc: 0.9695 - val_loss: 1.3027 - val_acc: 0.7442
# Epoch 85/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0721 - acc: 0.9706 - val_loss: 1.0072 - val_acc: 0.7930
# Epoch 86/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0738 - acc: 0.9696 - val_loss: 1.0729 - val_acc: 0.7657
# Epoch 87/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0717 - acc: 0.9706 - val_loss: 0.8649 - val_acc: 0.8041
# Epoch 88/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0718 - acc: 0.9702 - val_loss: 0.8964 - val_acc: 0.8034
# Epoch 89/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0700 - acc: 0.9711 - val_loss: 0.9628 - val_acc: 0.7799
# Epoch 90/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0656 - acc: 0.9730 - val_loss: 0.8134 - val_acc: 0.8266
# Epoch 91/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0615 - acc: 0.9748 - val_loss: 0.8711 - val_acc: 0.8124
# Epoch 92/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0562 - acc: 0.9773 - val_loss: 0.9042 - val_acc: 0.7959
# Epoch 93/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0552 - acc: 0.9776 - val_loss: 0.8193 - val_acc: 0.8269
# Epoch 94/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0572 - acc: 0.9766 - val_loss: 0.8479 - val_acc: 0.8114
# Epoch 95/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0582 - acc: 0.9763 - val_loss: 0.8897 - val_acc: 0.7887
# Epoch 96/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0566 - acc: 0.9765 - val_loss: 0.7979 - val_acc: 0.8294
# Epoch 97/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0538 - acc: 0.9779 - val_loss: 0.8035 - val_acc: 0.8224
# Epoch 98/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0485 - acc: 0.9804 - val_loss: 0.8478 - val_acc: 0.8229
# Epoch 99/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0451 - acc: 0.9819 - val_loss: 0.8055 - val_acc: 0.8364
# Epoch 100/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0465 - acc: 0.9812 - val_loss: 0.8687 - val_acc: 0.8047

# %%
# 降速训练1（0.0001）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.0001 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = EPOCHES
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 101/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0405 - acc: 0.9840 - val_loss: 0.8107 - val_acc: 0.8312
# Epoch 102/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0364 - acc: 0.9859 - val_loss: 0.8170 - val_acc: 0.8282
# Epoch 103/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0339 - acc: 0.9869 - val_loss: 0.8287 - val_acc: 0.8279
# Epoch 104/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0327 - acc: 0.9875 - val_loss: 0.8154 - val_acc: 0.8351
# Epoch 105/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0323 - acc: 0.9876 - val_loss: 0.8277 - val_acc: 0.8289
# Epoch 106/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0295 - acc: 0.9888 - val_loss: 0.8073 - val_acc: 0.8401
# Epoch 107/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0300 - acc: 0.9885 - val_loss: 0.8161 - val_acc: 0.8386
# Epoch 108/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0302 - acc: 0.9883 - val_loss: 0.8197 - val_acc: 0.8379
# Epoch 109/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0304 - acc: 0.9881 - val_loss: 0.7984 - val_acc: 0.8452
# Epoch 110/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0294 - acc: 0.9887 - val_loss: 0.8261 - val_acc: 0.8346
# Epoch 111/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0295 - acc: 0.9887 - val_loss: 0.8035 - val_acc: 0.8440
# Epoch 112/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0282 - acc: 0.9892 - val_loss: 0.8113 - val_acc: 0.8436
# Epoch 113/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0279 - acc: 0.9893 - val_loss: 0.8191 - val_acc: 0.8436
# Epoch 114/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0280 - acc: 0.9893 - val_loss: 0.8193 - val_acc: 0.8476
# Epoch 115/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0276 - acc: 0.9894 - val_loss: 0.8214 - val_acc: 0.8454
# Epoch 116/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0261 - acc: 0.9901 - val_loss: 0.8169 - val_acc: 0.8492
# Epoch 117/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0277 - acc: 0.9893 - val_loss: 0.8317 - val_acc: 0.8469
# Epoch 118/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0268 - acc: 0.9897 - val_loss: 0.8166 - val_acc: 0.8530
# Epoch 119/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0267 - acc: 0.9897 - val_loss: 0.8253 - val_acc: 0.8494
# Epoch 120/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0263 - acc: 0.9900 - val_loss: 0.8269 - val_acc: 0.8518
# Epoch 121/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0249 - acc: 0.9905 - val_loss: 0.8317 - val_acc: 0.8523
# Epoch 122/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0248 - acc: 0.9906 - val_loss: 0.8429 - val_acc: 0.8492
# Epoch 123/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0246 - acc: 0.9906 - val_loss: 0.8398 - val_acc: 0.8541
# Epoch 124/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0245 - acc: 0.9906 - val_loss: 0.8570 - val_acc: 0.8500
# Epoch 125/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0244 - acc: 0.9907 - val_loss: 0.8492 - val_acc: 0.8540
# Epoch 126/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0265 - acc: 0.9898 - val_loss: 0.8505 - val_acc: 0.8538
# Epoch 127/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0243 - acc: 0.9907 - val_loss: 0.8411 - val_acc: 0.8549
# Epoch 128/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0233 - acc: 0.9912 - val_loss: 0.8467 - val_acc: 0.8534
# Epoch 129/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0241 - acc: 0.9907 - val_loss: 0.8514 - val_acc: 0.8538
# Epoch 130/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0245 - acc: 0.9907 - val_loss: 0.8482 - val_acc: 0.8555
# Epoch 131/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0237 - acc: 0.9909 - val_loss: 0.8558 - val_acc: 0.8531
# Epoch 132/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0235 - acc: 0.9909 - val_loss: 0.8489 - val_acc: 0.8564
# Epoch 133/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0230 - acc: 0.9913 - val_loss: 0.8613 - val_acc: 0.8535
# Epoch 134/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0215 - acc: 0.9919 - val_loss: 0.8610 - val_acc: 0.8569
# Epoch 135/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0219 - acc: 0.9917 - val_loss: 0.8694 - val_acc: 0.8547
# Epoch 136/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0222 - acc: 0.9916 - val_loss: 0.8715 - val_acc: 0.8558
# Epoch 137/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0218 - acc: 0.9917 - val_loss: 0.8755 - val_acc: 0.8567
# Epoch 138/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0228 - acc: 0.9912 - val_loss: 0.8636 - val_acc: 0.8566
# Epoch 139/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0224 - acc: 0.9914 - val_loss: 0.8724 - val_acc: 0.8549
# Epoch 140/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0219 - acc: 0.9916 - val_loss: 0.8637 - val_acc: 0.8583
# Epoch 141/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0222 - acc: 0.9914 - val_loss: 0.8739 - val_acc: 0.8551
# Epoch 142/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0203 - acc: 0.9923 - val_loss: 0.8862 - val_acc: 0.8565
# Epoch 143/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0207 - acc: 0.9922 - val_loss: 0.8937 - val_acc: 0.8566
# Epoch 144/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0201 - acc: 0.9924 - val_loss: 0.8969 - val_acc: 0.8578
# Epoch 145/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0204 - acc: 0.9923 - val_loss: 0.9004 - val_acc: 0.8551
# Epoch 146/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0193 - acc: 0.9927 - val_loss: 0.9002 - val_acc: 0.8574
# Epoch 147/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0190 - acc: 0.9929 - val_loss: 0.9002 - val_acc: 0.8591
# Epoch 148/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0191 - acc: 0.9928 - val_loss: 0.9167 - val_acc: 0.8553
# Epoch 149/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0200 - acc: 0.9924 - val_loss: 0.9093 - val_acc: 0.8592
# Epoch 150/150
# 8/8 [==============================] - 9s 1s/step - loss: 0.0182 - acc: 0.9932 - val_loss: 0.9200 - val_acc: 0.8570

# %%
# 降速训练2（0.00001）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 151/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0183 - acc: 0.9931 - val_loss: 0.9224 - val_acc: 0.8574
# Epoch 152/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0172 - acc: 0.9938 - val_loss: 0.9233 - val_acc: 0.8590
# Epoch 153/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0175 - acc: 0.9936 - val_loss: 0.9263 - val_acc: 0.8587
# Epoch 154/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0177 - acc: 0.9935 - val_loss: 0.9304 - val_acc: 0.8578
# Epoch 155/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0179 - acc: 0.9934 - val_loss: 0.9321 - val_acc: 0.8575
# Epoch 156/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0169 - acc: 0.9939 - val_loss: 0.9343 - val_acc: 0.8579
# Epoch 157/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0174 - acc: 0.9936 - val_loss: 0.9373 - val_acc: 0.8577
# Epoch 158/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0173 - acc: 0.9937 - val_loss: 0.9389 - val_acc: 0.8575
# Epoch 159/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0165 - acc: 0.9941 - val_loss: 0.9400 - val_acc: 0.8576
# Epoch 160/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0163 - acc: 0.9942 - val_loss: 0.9429 - val_acc: 0.8577
# Epoch 161/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9942 - val_loss: 0.9456 - val_acc: 0.8579
# Epoch 162/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0168 - acc: 0.9939 - val_loss: 0.9477 - val_acc: 0.8575
# Epoch 163/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0168 - acc: 0.9939 - val_loss: 0.9500 - val_acc: 0.8577
# Epoch 164/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0169 - acc: 0.9939 - val_loss: 0.9511 - val_acc: 0.8573
# Epoch 165/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9943 - val_loss: 0.9519 - val_acc: 0.8576
# Epoch 166/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9941 - val_loss: 0.9544 - val_acc: 0.8575
# Epoch 167/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0166 - acc: 0.9940 - val_loss: 0.9561 - val_acc: 0.8575
# Epoch 168/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0168 - acc: 0.9939 - val_loss: 0.9565 - val_acc: 0.8572
# Epoch 169/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9941 - val_loss: 0.9578 - val_acc: 0.8574
# Epoch 170/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9941 - val_loss: 0.9592 - val_acc: 0.8573
# Epoch 171/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9941 - val_loss: 0.9605 - val_acc: 0.8573
# Epoch 172/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0164 - acc: 0.9941 - val_loss: 0.9612 - val_acc: 0.8577
# Epoch 173/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0172 - acc: 0.9937 - val_loss: 0.9614 - val_acc: 0.8570
# Epoch 174/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9637 - val_acc: 0.8564
# Epoch 175/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0158 - acc: 0.9944 - val_loss: 0.9643 - val_acc: 0.8572
# Epoch 176/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9942 - val_loss: 0.9663 - val_acc: 0.8575
# Epoch 177/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9942 - val_loss: 0.9673 - val_acc: 0.8571
# Epoch 178/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0171 - acc: 0.9937 - val_loss: 0.9685 - val_acc: 0.8568
# Epoch 179/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0163 - acc: 0.9941 - val_loss: 0.9671 - val_acc: 0.8573
# Epoch 180/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9687 - val_acc: 0.8577
# Epoch 181/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0167 - acc: 0.9939 - val_loss: 0.9704 - val_acc: 0.8565
# Epoch 182/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9696 - val_acc: 0.8567
# Epoch 183/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0171 - acc: 0.9938 - val_loss: 0.9681 - val_acc: 0.8569
# Epoch 184/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9942 - val_loss: 0.9681 - val_acc: 0.8571
# Epoch 185/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9942 - val_loss: 0.9698 - val_acc: 0.8565
# Epoch 186/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9703 - val_acc: 0.8568
# Epoch 187/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0166 - acc: 0.9939 - val_loss: 0.9715 - val_acc: 0.8568
# Epoch 188/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9717 - val_acc: 0.8569
# Epoch 189/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9942 - val_loss: 0.9734 - val_acc: 0.8570
# Epoch 190/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9942 - val_loss: 0.9732 - val_acc: 0.8571
# Epoch 191/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9735 - val_acc: 0.8570
# Epoch 192/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9941 - val_loss: 0.9744 - val_acc: 0.8573
# Epoch 193/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9760 - val_acc: 0.8567
# Epoch 194/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9944 - val_loss: 0.9793 - val_acc: 0.8562
# Epoch 195/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0158 - acc: 0.9943 - val_loss: 0.9805 - val_acc: 0.8570
# Epoch 196/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9796 - val_acc: 0.8575
# Epoch 197/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9944 - val_loss: 0.9786 - val_acc: 0.8577
# Epoch 198/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9804 - val_acc: 0.8573
# Epoch 199/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0167 - acc: 0.9938 - val_loss: 0.9821 - val_acc: 0.8565
# Epoch 200/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9943 - val_loss: 0.9801 - val_acc: 0.8572

# %%
# 降速训练3（0.00001/5）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 / 5 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 100  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 201/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9945 - val_loss: 0.9816 - val_acc: 0.8570
# Epoch 202/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9942 - val_loss: 0.9820 - val_acc: 0.8571
# Epoch 203/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9830 - val_acc: 0.8571
# Epoch 204/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9836 - val_acc: 0.8571
# Epoch 205/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9840 - val_acc: 0.8571
# Epoch 206/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9846 - val_acc: 0.8571
# Epoch 207/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0159 - acc: 0.9942 - val_loss: 0.9851 - val_acc: 0.8570
# Epoch 208/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9943 - val_loss: 0.9854 - val_acc: 0.8569
# Epoch 209/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9942 - val_loss: 0.9855 - val_acc: 0.8569
# Epoch 210/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9857 - val_acc: 0.8568
# Epoch 211/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9943 - val_loss: 0.9862 - val_acc: 0.8568
# Epoch 212/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9866 - val_acc: 0.8568
# Epoch 213/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0169 - acc: 0.9939 - val_loss: 0.9873 - val_acc: 0.8568
# Epoch 214/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9871 - val_acc: 0.8568
# Epoch 215/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9947 - val_loss: 0.9872 - val_acc: 0.8568
# Epoch 216/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9874 - val_acc: 0.8568
# Epoch 217/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9878 - val_acc: 0.8568
# Epoch 218/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9877 - val_acc: 0.8568
# Epoch 219/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0158 - acc: 0.9942 - val_loss: 0.9885 - val_acc: 0.8567
# Epoch 220/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9945 - val_loss: 0.9884 - val_acc: 0.8567
# Epoch 221/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9887 - val_acc: 0.8567
# Epoch 222/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9886 - val_acc: 0.8568
# Epoch 223/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9890 - val_acc: 0.8568
# Epoch 224/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9893 - val_acc: 0.8568
# Epoch 225/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 0.9896 - val_acc: 0.8567
# Epoch 226/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9898 - val_acc: 0.8567
# Epoch 227/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9943 - val_loss: 0.9888 - val_acc: 0.8569
# Epoch 228/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9889 - val_acc: 0.8569
# Epoch 229/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 0.9891 - val_acc: 0.8568
# Epoch 230/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0162 - acc: 0.9941 - val_loss: 0.9894 - val_acc: 0.8568
# Epoch 231/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0159 - acc: 0.9943 - val_loss: 0.9897 - val_acc: 0.8568
# Epoch 232/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9901 - val_acc: 0.8568
# Epoch 233/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9904 - val_acc: 0.8567
# Epoch 234/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 0.9905 - val_acc: 0.8567
# Epoch 235/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 0.9908 - val_acc: 0.8567
# Epoch 236/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9910 - val_acc: 0.8568
# Epoch 237/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9946 - val_loss: 0.9911 - val_acc: 0.8567
# Epoch 238/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9913 - val_acc: 0.8567
# Epoch 239/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9944 - val_loss: 0.9915 - val_acc: 0.8566
# Epoch 240/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9916 - val_acc: 0.8566
# Epoch 241/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0158 - acc: 0.9943 - val_loss: 0.9918 - val_acc: 0.8564
# Epoch 242/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9921 - val_acc: 0.8564
# Epoch 243/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9946 - val_loss: 0.9923 - val_acc: 0.8563
# Epoch 244/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9924 - val_acc: 0.8564
# Epoch 245/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 0.9926 - val_acc: 0.8564
# Epoch 246/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9944 - val_loss: 0.9928 - val_acc: 0.8565
# Epoch 247/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9932 - val_acc: 0.8565
# Epoch 248/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9938 - val_acc: 0.8565
# Epoch 249/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 0.9935 - val_acc: 0.8566
# Epoch 250/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9937 - val_acc: 0.8566
# Epoch 251/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9941 - val_acc: 0.8567
# Epoch 252/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 0.9948 - val_acc: 0.8567
# Epoch 253/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0160 - acc: 0.9943 - val_loss: 0.9946 - val_acc: 0.8569
# Epoch 254/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9945 - val_loss: 0.9947 - val_acc: 0.8568
# Epoch 255/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 0.9948 - val_acc: 0.8568
# Epoch 256/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.9952 - val_acc: 0.8567
# Epoch 257/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 0.9956 - val_acc: 0.8567
# Epoch 258/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 0.9960 - val_acc: 0.8566
# Epoch 259/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 0.9962 - val_acc: 0.8566
# Epoch 260/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 0.9968 - val_acc: 0.8566
# Epoch 261/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0158 - acc: 0.9942 - val_loss: 0.9969 - val_acc: 0.8567
# Epoch 262/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9947 - val_loss: 0.9966 - val_acc: 0.8568
# Epoch 263/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.9965 - val_acc: 0.8568
# Epoch 264/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 0.9966 - val_acc: 0.8567
# Epoch 265/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 0.9965 - val_acc: 0.8567
# Epoch 266/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9949 - val_loss: 0.9968 - val_acc: 0.8566
# Epoch 267/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9973 - val_acc: 0.8565
# Epoch 268/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0161 - acc: 0.9942 - val_loss: 0.9970 - val_acc: 0.8567
# Epoch 269/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 0.9971 - val_acc: 0.8566
# Epoch 270/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0145 - acc: 0.9949 - val_loss: 0.9973 - val_acc: 0.8566
# Epoch 271/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 0.9977 - val_acc: 0.8567
# Epoch 272/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 0.9983 - val_acc: 0.8568
# Epoch 273/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 0.9985 - val_acc: 0.8568
# Epoch 274/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.9986 - val_acc: 0.8568
# Epoch 275/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 0.9990 - val_acc: 0.8568
# Epoch 276/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.9992 - val_acc: 0.8568
# Epoch 277/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9947 - val_loss: 0.9989 - val_acc: 0.8567
# Epoch 278/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 0.9988 - val_acc: 0.8567
# Epoch 279/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9992 - val_acc: 0.8567
# Epoch 280/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 0.9991 - val_acc: 0.8567
# Epoch 281/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0157 - acc: 0.9943 - val_loss: 0.9992 - val_acc: 0.8567
# Epoch 282/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9944 - val_loss: 0.9994 - val_acc: 0.8566
# Epoch 283/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 0.9995 - val_acc: 0.8565
# Epoch 284/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9944 - val_loss: 0.9993 - val_acc: 0.8564
# Epoch 285/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.9990 - val_acc: 0.8566
# Epoch 286/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 0.9992 - val_acc: 0.8567
# Epoch 287/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 0.9992 - val_acc: 0.8568
# Epoch 288/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0156 - acc: 0.9943 - val_loss: 0.9989 - val_acc: 0.8569
# Epoch 289/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 0.9992 - val_acc: 0.8569
# Epoch 290/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 1.0000 - val_acc: 0.8567
# Epoch 291/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9945 - val_loss: 1.0000 - val_acc: 0.8566
# Epoch 292/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0001 - val_acc: 0.8567
# Epoch 293/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 1.0003 - val_acc: 0.8567
# Epoch 294/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0009 - val_acc: 0.8566
# Epoch 295/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9944 - val_loss: 1.0011 - val_acc: 0.8567
# Epoch 296/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9945 - val_loss: 1.0011 - val_acc: 0.8566
# Epoch 297/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0010 - val_acc: 0.8567
# Epoch 298/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9945 - val_loss: 1.0009 - val_acc: 0.8567
# Epoch 299/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 1.0010 - val_acc: 0.8567
# Epoch 300/300
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0011 - val_acc: 0.8567

# %%
# 降速训练4（0.00001/10）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 / 10 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 301/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 1.0015 - val_acc: 0.8567
# Epoch 302/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 1.0014 - val_acc: 0.8568
# Epoch 303/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 1.0016 - val_acc: 0.8567
# Epoch 304/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 1.0016 - val_acc: 0.8568
# Epoch 305/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0020 - val_acc: 0.8567
# Epoch 306/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 1.0023 - val_acc: 0.8568
# Epoch 307/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 1.0025 - val_acc: 0.8567
# Epoch 308/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 1.0028 - val_acc: 0.8567
# Epoch 309/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0143 - acc: 0.9951 - val_loss: 1.0027 - val_acc: 0.8567
# Epoch 310/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0027 - val_acc: 0.8568
# Epoch 311/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0029 - val_acc: 0.8567
# Epoch 312/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0028 - val_acc: 0.8567
# Epoch 313/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0145 - acc: 0.9950 - val_loss: 1.0030 - val_acc: 0.8567
# Epoch 314/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0033 - val_acc: 0.8567
# Epoch 315/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0034 - val_acc: 0.8566
# Epoch 316/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0154 - acc: 0.9944 - val_loss: 1.0035 - val_acc: 0.8566
# Epoch 317/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0035 - val_acc: 0.8566
# Epoch 318/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 1.0037 - val_acc: 0.8566
# Epoch 319/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 1.0037 - val_acc: 0.8566
# Epoch 320/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9948 - val_loss: 1.0038 - val_acc: 0.8567
# Epoch 321/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0043 - val_acc: 0.8567
# Epoch 322/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0043 - val_acc: 0.8567
# Epoch 323/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 1.0046 - val_acc: 0.8566
# Epoch 324/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0042 - val_acc: 0.8566
# Epoch 325/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0041 - val_acc: 0.8567
# Epoch 326/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0155 - acc: 0.9944 - val_loss: 1.0041 - val_acc: 0.8567
# Epoch 327/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9948 - val_loss: 1.0041 - val_acc: 0.8567
# Epoch 328/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 1.0041 - val_acc: 0.8567
# Epoch 329/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0145 - acc: 0.9949 - val_loss: 1.0044 - val_acc: 0.8566
# Epoch 330/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9946 - val_loss: 1.0045 - val_acc: 0.8566
# Epoch 331/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0149 - acc: 0.9947 - val_loss: 1.0046 - val_acc: 0.8566
# Epoch 332/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 1.0047 - val_acc: 0.8567
# Epoch 333/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0151 - acc: 0.9946 - val_loss: 1.0051 - val_acc: 0.8566
# Epoch 334/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 1.0055 - val_acc: 0.8566
# Epoch 335/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9948 - val_loss: 1.0054 - val_acc: 0.8566
# Epoch 336/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9948 - val_loss: 1.0054 - val_acc: 0.8566
# Epoch 337/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9948 - val_loss: 1.0056 - val_acc: 0.8566
# Epoch 338/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0059 - val_acc: 0.8566
# Epoch 339/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9945 - val_loss: 1.0060 - val_acc: 0.8566
# Epoch 340/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0145 - acc: 0.9949 - val_loss: 1.0059 - val_acc: 0.8566
# Epoch 341/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0058 - val_acc: 0.8566
# Epoch 342/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0152 - acc: 0.9946 - val_loss: 1.0058 - val_acc: 0.8565
# Epoch 343/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 1.0057 - val_acc: 0.8566
# Epoch 344/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0146 - acc: 0.9949 - val_loss: 1.0057 - val_acc: 0.8566
# Epoch 345/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 1.0057 - val_acc: 0.8566
# Epoch 346/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0150 - acc: 0.9947 - val_loss: 1.0057 - val_acc: 0.8566
# Epoch 347/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9945 - val_loss: 1.0058 - val_acc: 0.8566
# Epoch 348/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0147 - acc: 0.9948 - val_loss: 1.0060 - val_acc: 0.8566
# Epoch 349/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0153 - acc: 0.9946 - val_loss: 1.0061 - val_acc: 0.8566
# Epoch 350/350
# 8/8 [==============================] - 9s 1s/step - loss: 0.0148 - acc: 0.9947 - val_loss: 1.0062 - val_acc: 0.8566

# %%
# 备用模型保存函数 + 导入：保存当前模型 —— 临时保存在当前目录下。
model.save( 'model4_100.h5' )
new_model = tf.keras.models.load_model( 'model4_100.h5' )

# %% [markdown]
# ### 5. 查看效果：

# %%
# 模型加载：因为保存的是全体模型，所以直接直接导入即可（和导入.h5文件方式一样！）
new_model = tf.keras.models.load_model( '/home/gaoboyu/学习保存的模型/沙漠4' )  # 括号里写model的地址

# %%
# 在训练数据上看效果：
num = 10 # 一次看5张效果！

for image, label_real in train_dataset.take(1):
    label_pred = new_model.predict(image)
    label_pred = tf.argmax( label_pred, axis = -1 )  # 每个维度上，取一个最大值！
    
    plt.figure( figsize=(20,20) )
    # 每行3张图，从左到右：原图、真实标签图、预测标签图
    for i in range(num):
        plt.subplot(num, 3, i*3 + 1)
        plt.imshow( (image[i].numpy() + 1)/2 )
        plt.subplot(num, 3, i*3 + 2)
        plt.imshow( label_real[i].numpy().reshape(256,256) )
        plt.subplot(num, 3, i*3 + 3)
        plt.imshow( label_pred[i].numpy().reshape(256,256) )

# %%
# 查看当前图有标签为 “1” 的像素点有多少个：

# %%
label_pred.shape
# Out:
# TensorShape([10, 256, 256])

# %%
np.unique(label_pred[3])
# Out:
# array([0, 1])

# %%
from collections import Counter
img1 = label_pred[1].numpy()
result = dict( Counter(img1.flatten()) )
result = sorted(result.items(), key = lambda item:item[1], reverse=True)
result
# Out:
# [(0, 56288), (1, 9248)]

# %%
# 用当前模型测试一张图：
img_test = glob.glob( r'/home/gaoboyu/学习数据集/沙漠数据集3/subimg_172.png' )

img_test = read_image(img_test[0])
img_test = tf.expand_dims( img_test, axis = 0 )

label_pred = new_model.predict(img_test)
label_pred = tf.argmax( label_pred, axis = -1 )  # 每个维度上，取一个最大值！

img_test = tf.squeeze( img_test, axis = 0 )

plt.figure( figsize=(10,10) )
plt.subplot(1, 2, 1)
plt.imshow( img_test.numpy() )
plt.subplot(1, 2, 2)
plt.imshow( label_pred[0].numpy().reshape(256,256) )

# %%
np.unique(label_pred)
# Out:
# array([0, 1])

# %%
from collections import Counter
img1 = label_pred.numpy()
result = dict( Counter(img1.flatten()) )
result = sorted(result.items(), key = lambda item:item[1], reverse=True)
result
# Out:
# [(0, 65008), (1, 528)]
