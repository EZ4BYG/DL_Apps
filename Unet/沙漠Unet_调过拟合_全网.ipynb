# %%
import tensorflow as tf
import numpy as np
import glob 
import os
import matplotlib.pyplot as plt
import matplotlib
import scipy

# %%
gpus = tf.config.experimental.list_physical_devices( device_type = 'GPU' )
# 设置该程序可见的GPU：写到最前面！
tf.config.experimental.set_visible_devices( devices = gpus[3:5], device_type = 'GPU' )

# %% [markdown]
# ### 1. 导入所有文件的路径：

# %%
# 所有训练图片的地址：
image_path = glob.glob( '/home/gaoboyu/学习数据集/沙漠数据集9_300/图像/*' )
label_path = glob.glob( '/home/gaoboyu/学习数据集/沙漠数据集9_300/处理后标签/*' )

# %%
image_count = len(image_path)
len(image_path), len(label_path)
# Out:
# (300, 300)

# %%
# 训练数据的乱序：
index = np.random.permutation( image_count )
image_path = np.array(image_path)[index]
label_path = np.array(label_path)[index]

# %%
# 查看是否对应：
image_path[21:23], label_path[21:23]
# Out:
# (array(['/home/gaoboyu/学习数据集/沙漠数据集9_300/图像/subimg_96.png',
#         '/home/gaoboyu/学习数据集/沙漠数据集9_300/图像/subimg_98.png'], dtype='<U49'),
#  array(['/home/gaoboyu/学习数据集/沙漠数据集9_300/处理后标签/subimg_96.png',
#         '/home/gaoboyu/学习数据集/沙漠数据集9_300/处理后标签/subimg_98.png'], dtype='<U52'))

# %% [markdown]
# ### 2. 创建数据集：

# %%
dataset = tf.data.Dataset.from_tensor_slices( (image_path, label_path) )

# %%
# 划分训练、测试集
val_count = int( image_count*0.2 )
train_count = image_count - val_count

train_dataset = dataset.skip(val_count)  # 跳过前这么多数据
val_dataset = dataset.take(val_count)   # 取前面这么多数据

# %%
# 查看：
train_dataset, val_dataset
# Out:
# (<SkipDataset shapes: ((), ()), types: (tf.string, tf.string)>,
#  <TakeDataset shapes: ((), ()), types: (tf.string, tf.string)>)

# %%
val_count, train_count
# Out:
# (60, 240)

# %% [markdown]
# ### 3. 预处理函数：

# %%
# 读取图片：3通道
def read_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels = 3)
    return img

# %%
# 读取标签：1通道（每个像素都是标签值）
def read_label(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels = 1)
    return img

# %%
# 对训练数据及标签：随机翻转 —— 训练数据专用！
def random_flip(img, label):
    img_label = tf.concat( [img, label], axis = -1 )  # 图像与标签合并
    img_label = tf.image.resize(img_label, [256,256])
    img_label = tf.image.random_flip_left_right(img_label)  # 随机左右翻转
    img_label = tf.image.random_flip_up_down(img_label)     # 随机上下翻转
    return img_label[:,:,0:3], img_label[:,:,3:]

# %%
# 所有图像归一化 + 标签转数据类型：
def normal(img, label):
    img = tf.cast(img, tf.float32) / 127.5 - 1
    label = tf.cast(label, tf.int32)  # 不能减1，因为里面本身就有0的标签！ 
    return img, label

# %%
# 训练数据加载：需要裁减！
def load_train_image(img_path, label_path):
    # 获取图片与标签：
    img = read_image(img_path)
    label = read_label(label_path)
    # 预处理：随机翻转 —— 自带统一形状！
    img, label = random_flip(img, label)
    # 返回归一化：
    return normal(img, label)

def load_val_image(img_path, label_path):
    # 获取图片与标签：
    img = read_image(img_path)
    label = read_label(label_path)
    # 统一形状：
    img = tf.image.resize(img, [256,256])
    label = tf.image.resize(label, [256,256])
    # 返回归一化：
    return normal(img, label)

# %%
# 将数据应用于函数：
AUTOTUNE = tf.data.experimental.AUTOTUNE   # 多线程加载：图像加载是cpu处理的，cpu可以做多线程！

train_dataset = train_dataset.map( load_train_image, num_parallel_calls = AUTOTUNE )
val_dataset = val_dataset.map( load_val_image, num_parallel_calls = AUTOTUNE )

# %%
train_dataset, val_dataset
# Out:
# (<ParallelMapDataset shapes: ((256, 256, 3), (256, 256, 1)), types: (tf.float32, tf.int32)>,
#  <ParallelMapDataset shapes: ((256, 256, 3), (256, 256, 1)), types: (tf.float32, tf.int32)>)

# %%
# 乱序、划分数据集：
# cashe()：新操作，文件不断放到缓存中，加速！
# prefetch()：新操作，GPU内存不等待，不断预处理图片
BATCH_SIZE = 10
train_dataset = train_dataset.cache().shuffle(train_count).repeat().batch(BATCH_SIZE).prefetch(AUTOTUNE)
val_dataset = val_dataset.cache().batch(BATCH_SIZE)

# %%
train_dataset, val_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>,
#  <BatchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.int32)>)

# %% [markdown]
# ### 4. 模型搭建：Dropout + BatchNormalization

# %%
# 以后把模型的自定义，都写到一个函数里 正规！—— 没有输入数据，返回一个模型！—— 层的生成，完全可以用循环！
# 调过拟合：每个Conv层后都加一个Dropout层！
def create_model():
    inputs = tf.keras.layers.Input( shape = (256,256,3) )  # 所有的层都是大写的！所有这也是一个层！
    
    # 前半部分卷积基自定义：顺序连接 + 用名字获得某层输出
    # 第一部分：_1
    conv2d_1_1 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_1_1' )(inputs)
    dropout_1_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_1_1' )(conv2d_1_1)  # dropout
    bn_1_1 = tf.keras.layers.BatchNormalization( name = 'bn_1_1' )(dropout_1_1)
    conv2d_1_2 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_1_2' )(bn_1_1)
    dropout_1_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_1_2' )(conv2d_1_2)  # dropout
    bn_1_2 = tf.keras.layers.BatchNormalization( name = 'bn_1_2' )(dropout_1_2)  # 256 x 256 x 64 √
    maxpool_1_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_1_1' )(bn_1_2)   # 128 x 128 x 64
    
    # 第二部分：_2
    conv2d_2_1 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_2_1' )(maxpool_1_1)
    dropout_2_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_2_1' )(conv2d_2_1)  # dropout
    bn_2_1 = tf.keras.layers.BatchNormalization( name = 'bn_2_1' )(dropout_2_1)
    conv2d_2_2 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_2_2' )(bn_2_1)
    dropout_2_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_2_2' )(conv2d_2_2)  # dropout
    bn_2_2 = tf.keras.layers.BatchNormalization( name = 'bn_2_2' )(dropout_2_2)  # 128 x 128 x 128 √
    maxpool_2_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_2_1' )(bn_2_2)   # 64 x 64 x 128
    
    # 第三部分：_3
    conv2d_3_1 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_3_1' )(maxpool_2_1)
    dropout_3_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_3_1' )(conv2d_3_1)  # dropout
    bn_3_1 = tf.keras.layers.BatchNormalization( name = 'bn_3_1' )(dropout_3_1)
    conv2d_3_2 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_3_2' )(bn_3_1)
    dropout_3_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_3_2' )(conv2d_3_2)  # dropout
    bn_3_2 = tf.keras.layers.BatchNormalization( name = 'bn_3_2' )(dropout_3_2)  # 64 x 64 x 256 √
    maxpool_3_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_3_1' )(bn_3_2)   # 32 x 32 x 256
    
    # 第四部分：_4
    conv2d_4_1 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_4_1' )(maxpool_3_1)
    dropout_4_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_4_1' )(conv2d_4_1)  # dropout
    bn_4_1 = tf.keras.layers.BatchNormalization( name = 'bn_4_1' )(dropout_4_1)
    conv2d_4_2 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_4_2' )(bn_4_1)
    dropout_4_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_4_2' )(conv2d_4_2)  # dropout
    bn_4_2 = tf.keras.layers.BatchNormalization( name = 'bn_4_2' )(dropout_4_2)  # 32 x 32 x 512 √
    maxpool_4_1 = tf.keras.layers.MaxPooling2D( name = 'maxpool_4_1' )(bn_4_2)   # 16 x 16 x 512  
    
    # 第五部分：_5 —— 最后没下采样！
    conv2d_5_1 = tf.keras.layers.Conv2D( 1024, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_5_1' )(maxpool_4_1)
    dropout_5_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_5_1' )(conv2d_5_1)  # dropout
    bn_5_1 = tf.keras.layers.BatchNormalization( name = 'bn_5_1' )(dropout_5_1)
    conv2d_5_2 = tf.keras.layers.Conv2D( 1024, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_5_2' )(bn_5_1)
    dropout_5_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_5_2' )(conv2d_5_2)  # dropout
    bn_5_2 = tf.keras.layers.BatchNormalization( name = 'bn_5_2' )(dropout_5_2)  # 16 x 16 x 1024
    
    
    # 后半部分自定义：反卷积 + 跳接（带√的）
    # 调过拟合：每个Conv层后都加一个Dropout层！
    
    # 第一部分：x1、x2
    # 上采样：上采用的卷积核是(2,2)
    x1 = tf.keras.layers.Conv2DTranspose( 512, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x1')(bn_5_2)
    bn_x1 = tf.keras.layers.BatchNormalization( name = 'bn_x1' )(x1)  # 32 x 32 x 512
    # 跳接合并：当成一个层！—— 每个Conv后跟一个Dropout
    x2 = tf.concat( [bn_x1, bn_4_2], axis = -1 )  # 32 x 32 x (512+512) = 32 x 32 x 1024
    conv2d_x2_1 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x2_1' )(x2)
    dropout_x2_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x2_1' )(conv2d_x2_1)  # dropout
    bn_x2_1 = tf.keras.layers.BatchNormalization( name = 'bn_x2_1' )(dropout_x2_1)
    conv2d_x2_2 = tf.keras.layers.Conv2D( 512, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x2_2' )(bn_x2_1)
    dropout_x2_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x2_2' )(conv2d_x2_2)  # dropout
    bn_x2_2 = tf.keras.layers.BatchNormalization( name = 'bn_x2_2' )(dropout_x2_2)  # 32 x 32 x 512
    
    # 第二部分：x3、x4
    # 上采样：上采用的卷积核是(2,2)
    x3 = tf.keras.layers.Conv2DTranspose( 256, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x3')(bn_x2_2)
    bn_x3 = tf.keras.layers.BatchNormalization( name = 'bn_x3' )(x3)  # 64 x 64 x 256
    # 跳接合并：当成一个层！—— 每个Conv后跟一个Dropout
    x4 = tf.concat( [bn_x3, bn_3_2], axis = -1 )  # 64 x 64 x (256+256) = 64 x 64 x 512
    conv2d_x4_1 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x4_1' )(x4)
    dropout_x4_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x4_1' )(conv2d_x4_1)  # dropout
    bn_x4_1 = tf.keras.layers.BatchNormalization( name = 'bn_x4_1' )(dropout_x4_1)
    conv2d_x4_2 = tf.keras.layers.Conv2D( 256, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x4_2' )(bn_x4_1)
    dropout_x4_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x4_2' )(conv2d_x4_2)  # dropout
    bn_x4_2 = tf.keras.layers.BatchNormalization( name = 'bn_x4_2' )(dropout_x4_2)  # 64 x 64 x 256
    
    # 第三部分：x5、x6
    # 上采样：上采用的卷积核是(2,2)
    x5 = tf.keras.layers.Conv2DTranspose( 128, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x5')(bn_x4_2)
    bn_x5 = tf.keras.layers.BatchNormalization( name = 'bn_x5' )(x5)  # 128 x 128 x 128
    # 跳接合并：当成一个层！—— 每个Conv后跟一个Dropout
    x6 = tf.concat( [bn_x5, bn_2_2], axis = -1 )  # 128 x 128 x (128+128) = 128 x 128 x 256
    conv2d_x6_1 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x6_1' )(x6)
    dropout_x6_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x6_1' )(conv2d_x6_1)  # dropout
    bn_x6_1 = tf.keras.layers.BatchNormalization( name = 'bn_x6_1' )(dropout_x6_1)
    conv2d_x6_2 = tf.keras.layers.Conv2D( 128, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x6_2' )(bn_x6_1)
    dropout_x6_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x6_2' )(conv2d_x6_2)  # dropout
    bn_x6_2 = tf.keras.layers.BatchNormalization( name = 'bn_x6_2' )(dropout_x6_2)  # 128 x 128 x 128
    
    # 第四部分：x7、x8
    # 上采样：上采用的卷积核是(2,2)
    x7 = tf.keras.layers.Conv2DTranspose( 64, (2,2), strides = 2, activation = 'relu', padding = 'same', name = 'x7' )(bn_x6_2)
    bn_x7 = tf.keras.layers.BatchNormalization( name = 'bn_x7' )(x7)  # 256 x 256 x 64
    # 跳接合并：当成一个层！—— 每个Conv后跟一个Dropout
    x8 = tf.concat( [bn_x7, bn_1_2], axis = -1 )  # 256 x 256 x (64+64) = 256 x 256 x 128
    conv2d_x8_1 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x8_1' )(x8)
    dropout_x8_1 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x8_1' )(conv2d_x8_1)  # dropout
    bn_x8_1 = tf.keras.layers.BatchNormalization( name = 'bn_x8_1' )(dropout_x8_1)
    conv2d_x8_2 = tf.keras.layers.Conv2D( 64, (3,3), padding = 'same', activation = 'relu', name = 'conv2d_x8_2' )(bn_x8_1)
    dropout_x8_2 = tf.keras.layers.Dropout( 0.1, name = 'dropout_x8_2' )(conv2d_x8_2)  # dropout
    bn_x8_2 = tf.keras.layers.BatchNormalization( name = 'bn_x8_2' )(dropout_x8_2)  # 256 x 256 x 64
    
    # 最后的通道数变为34：卷积核为(1,1)；激活函数用softmax
    # 最后输出大小：256 x 256 x 2
    output = tf.keras.layers.Conv2D(2, kernel_size = (1,1), strides = (1,1), padding = 'same', activation = 'softmax', name = 'output')(bn_x8_2)
    
    # 模型搭建：
    model = tf.keras.Model( inputs = inputs, outputs = output )
    return model

# %%
model = create_model()

# %%
# 模型编译
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# %%
# 定义保存模型的回调函数：保存整个模型、只保存最好的！
# 设置保存的路径：
checkpoint_path = '/home/gaoboyu/学习保存的模型/沙漠9_全网'
# 设置回调函数保存模型：没设置的参数都默认
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path,
    monitor = 'val_acc',
    save_best_only = True  # 监控的目标：如果新的epoch结果比前一个要好，那就重新保存最新的，删掉旧的！
)

# %%
# 模型训练
EPOCHES = 100
history = model.fit(
    train_dataset,
    epochs = EPOCHES,
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 1/100
# 24/24 [==============================] - ETA: 0s - loss: 0.6200 - acc: 0.8001WARNING:tensorflow:From /usr/local/Anaconda33/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 46s 2s/step - loss: 0.6200 - acc: 0.8001 - val_loss: 5.2254 - val_acc: 0.2055
# Epoch 2/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.4435 - acc: 0.8963 - val_loss: 13.8450 - val_acc: 0.1408
# Epoch 3/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.3611 - acc: 0.9045 - val_loss: 13.7889 - val_acc: 0.1417
# Epoch 4/100
# 24/24 [==============================] - ETA: 0s - loss: 0.2892 - acc: 0.9125INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 42s 2s/step - loss: 0.2892 - acc: 0.9125 - val_loss: 5.2986 - val_acc: 0.2312
# Epoch 5/100
# 24/24 [==============================] - ETA: 0s - loss: 0.2515 - acc: 0.9161INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 42s 2s/step - loss: 0.2515 - acc: 0.9161 - val_loss: 0.6596 - val_acc: 0.6477
# Epoch 6/100
# 24/24 [==============================] - ETA: 0s - loss: 0.2281 - acc: 0.9174INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.2281 - acc: 0.9174 - val_loss: 0.3858 - val_acc: 0.8666
# Epoch 7/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.2086 - acc: 0.9211 - val_loss: 0.4347 - val_acc: 0.8592
# Epoch 8/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.2020 - acc: 0.9224 - val_loss: 0.5318 - val_acc: 0.7839
# Epoch 9/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1991 - acc: 0.9224 - val_loss: 0.3016 - val_acc: 0.8651
# Epoch 10/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1938 - acc: 0.9239INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 42s 2s/step - loss: 0.1938 - acc: 0.9239 - val_loss: 0.3454 - val_acc: 0.8698
# Epoch 11/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1908 - acc: 0.9243INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 42s 2s/step - loss: 0.1908 - acc: 0.9243 - val_loss: 0.2980 - val_acc: 0.8739
# Epoch 12/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1866 - acc: 0.9255INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1866 - acc: 0.9255 - val_loss: 0.3060 - val_acc: 0.8812
# Epoch 13/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1789 - acc: 0.9285 - val_loss: 0.3962 - val_acc: 0.8771
# Epoch 14/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1810 - acc: 0.9272INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 42s 2s/step - loss: 0.1810 - acc: 0.9272 - val_loss: 0.2563 - val_acc: 0.8947
# Epoch 15/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1751 - acc: 0.9295 - val_loss: 0.3007 - val_acc: 0.8806
# Epoch 16/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1730 - acc: 0.9297INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1730 - acc: 0.9297 - val_loss: 0.2563 - val_acc: 0.8952
# Epoch 17/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1726 - acc: 0.9295 - val_loss: 0.4159 - val_acc: 0.8003
# Epoch 18/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1715 - acc: 0.9301 - val_loss: 0.3205 - val_acc: 0.8834
# Epoch 19/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1703 - acc: 0.9300 - val_loss: 0.3610 - val_acc: 0.8487
# Epoch 20/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1661 - acc: 0.9320 - val_loss: 0.2815 - val_acc: 0.8776
# Epoch 21/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1652 - acc: 0.9325INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1652 - acc: 0.9325 - val_loss: 0.2221 - val_acc: 0.9030
# Epoch 22/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1635 - acc: 0.9324INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1635 - acc: 0.9324 - val_loss: 0.2189 - val_acc: 0.9079
# Epoch 23/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1627 - acc: 0.9327INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 44s 2s/step - loss: 0.1627 - acc: 0.9327 - val_loss: 0.2125 - val_acc: 0.9171
# Epoch 24/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1594 - acc: 0.9343 - val_loss: 0.2120 - val_acc: 0.9126
# Epoch 25/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1566 - acc: 0.9351INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1566 - acc: 0.9351 - val_loss: 0.2017 - val_acc: 0.9178
# Epoch 26/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1628 - acc: 0.9324 - val_loss: 0.2260 - val_acc: 0.9094
# Epoch 27/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1558 - acc: 0.9351INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 44s 2s/step - loss: 0.1558 - acc: 0.9351 - val_loss: 0.1969 - val_acc: 0.9196
# Epoch 28/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1551 - acc: 0.9353INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1551 - acc: 0.9353 - val_loss: 0.1939 - val_acc: 0.9233
# Epoch 29/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1523 - acc: 0.9367INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1523 - acc: 0.9367 - val_loss: 0.1850 - val_acc: 0.9236
# Epoch 30/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1508 - acc: 0.9374INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1508 - acc: 0.9374 - val_loss: 0.1819 - val_acc: 0.9244
# Epoch 31/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1536 - acc: 0.9362 - val_loss: 0.2445 - val_acc: 0.9151
# Epoch 32/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1568 - acc: 0.9345 - val_loss: 0.1919 - val_acc: 0.9210
# Epoch 33/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1511 - acc: 0.9365INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 44s 2s/step - loss: 0.1511 - acc: 0.9365 - val_loss: 0.1859 - val_acc: 0.9247
# Epoch 34/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1485 - acc: 0.9377 - val_loss: 0.1920 - val_acc: 0.9218
# Epoch 35/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1478 - acc: 0.9380 - val_loss: 0.1809 - val_acc: 0.9242
# Epoch 36/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1466 - acc: 0.9382 - val_loss: 0.1927 - val_acc: 0.9225
# Epoch 37/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1443 - acc: 0.9394 - val_loss: 0.1988 - val_acc: 0.9217
# Epoch 38/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1417 - acc: 0.9402 - val_loss: 0.1956 - val_acc: 0.9217
# Epoch 39/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1413 - acc: 0.9403 - val_loss: 0.1905 - val_acc: 0.9223
# Epoch 40/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1398 - acc: 0.9409 - val_loss: 0.1917 - val_acc: 0.9241
# Epoch 41/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1356 - acc: 0.9426 - val_loss: 0.1869 - val_acc: 0.9215
# Epoch 42/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1360 - acc: 0.9422INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1360 - acc: 0.9422 - val_loss: 0.1848 - val_acc: 0.9250
# Epoch 43/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1333 - acc: 0.9432 - val_loss: 0.2006 - val_acc: 0.9238
# Epoch 44/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1321 - acc: 0.9438 - val_loss: 0.2013 - val_acc: 0.9209
# Epoch 45/100
# 24/24 [==============================] - ETA: 0s - loss: 0.1322 - acc: 0.9439INFO:tensorflow:Assets written to: /home/gaoboyu/学习保存的模型/沙漠9_全网/assets
# 24/24 [==============================] - 43s 2s/step - loss: 0.1322 - acc: 0.9439 - val_loss: 0.1831 - val_acc: 0.9268
# Epoch 46/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1307 - acc: 0.9444 - val_loss: 0.2006 - val_acc: 0.9202
# Epoch 47/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1335 - acc: 0.9429 - val_loss: 0.1943 - val_acc: 0.9255
# Epoch 48/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1279 - acc: 0.9453 - val_loss: 0.2058 - val_acc: 0.9204
# Epoch 49/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1238 - acc: 0.9472 - val_loss: 0.2213 - val_acc: 0.9218
# Epoch 50/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1203 - acc: 0.9487 - val_loss: 0.1998 - val_acc: 0.9252
# Epoch 51/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1207 - acc: 0.9482 - val_loss: 0.2089 - val_acc: 0.9198
# Epoch 52/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1163 - acc: 0.9502 - val_loss: 0.2056 - val_acc: 0.9239
# Epoch 53/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1180 - acc: 0.9497 - val_loss: 0.2092 - val_acc: 0.9247
# Epoch 54/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1191 - acc: 0.9490 - val_loss: 0.1969 - val_acc: 0.9253
# Epoch 55/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1187 - acc: 0.9493 - val_loss: 0.2005 - val_acc: 0.9235
# Epoch 56/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1145 - acc: 0.9513 - val_loss: 0.2145 - val_acc: 0.9202
# Epoch 57/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1129 - acc: 0.9516 - val_loss: 0.1987 - val_acc: 0.9219
# Epoch 58/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1115 - acc: 0.9520 - val_loss: 0.2406 - val_acc: 0.9139
# Epoch 59/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1120 - acc: 0.9517 - val_loss: 0.2210 - val_acc: 0.9191
# Epoch 60/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1042 - acc: 0.9554 - val_loss: 0.2112 - val_acc: 0.9227
# Epoch 61/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1023 - acc: 0.9560 - val_loss: 0.2291 - val_acc: 0.9171
# Epoch 62/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1001 - acc: 0.9570 - val_loss: 0.2127 - val_acc: 0.9245
# Epoch 63/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1009 - acc: 0.9562 - val_loss: 0.2233 - val_acc: 0.9188
# Epoch 64/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0983 - acc: 0.9577 - val_loss: 0.2138 - val_acc: 0.9234
# Epoch 65/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1019 - acc: 0.9557 - val_loss: 0.1952 - val_acc: 0.9248
# Epoch 66/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1015 - acc: 0.9566 - val_loss: 0.2185 - val_acc: 0.9234
# Epoch 67/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0969 - acc: 0.9584 - val_loss: 0.2153 - val_acc: 0.9220
# Epoch 68/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0975 - acc: 0.9578 - val_loss: 0.2141 - val_acc: 0.9240
# Epoch 69/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0935 - acc: 0.9597 - val_loss: 0.2241 - val_acc: 0.9241
# Epoch 70/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0902 - acc: 0.9612 - val_loss: 0.2236 - val_acc: 0.9251
# Epoch 71/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0949 - acc: 0.9595 - val_loss: 0.2317 - val_acc: 0.9239
# Epoch 72/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0925 - acc: 0.9600 - val_loss: 0.2434 - val_acc: 0.9221
# Epoch 73/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0891 - acc: 0.9615 - val_loss: 0.2453 - val_acc: 0.9183
# Epoch 74/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0866 - acc: 0.9627 - val_loss: 0.2435 - val_acc: 0.9220
# Epoch 75/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0854 - acc: 0.9634 - val_loss: 0.2412 - val_acc: 0.9235
# Epoch 76/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0825 - acc: 0.9645 - val_loss: 0.2311 - val_acc: 0.9232
# Epoch 77/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0813 - acc: 0.9650 - val_loss: 0.2556 - val_acc: 0.9187
# Epoch 78/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0813 - acc: 0.9649 - val_loss: 0.2294 - val_acc: 0.9196
# Epoch 79/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0921 - acc: 0.9618 - val_loss: 0.2217 - val_acc: 0.9217
# Epoch 80/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.1101 - acc: 0.9537 - val_loss: 0.2203 - val_acc: 0.9209
# Epoch 81/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0990 - acc: 0.9577 - val_loss: 0.2322 - val_acc: 0.9215
# Epoch 82/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0911 - acc: 0.9607 - val_loss: 0.2204 - val_acc: 0.9227
# Epoch 83/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0841 - acc: 0.9637 - val_loss: 0.2485 - val_acc: 0.9205
# Epoch 84/100
# 24/24 [==============================] - 55s 2s/step - loss: 0.0805 - acc: 0.9653 - val_loss: 0.2372 - val_acc: 0.9220
# Epoch 85/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0784 - acc: 0.9662 - val_loss: 0.2329 - val_acc: 0.9248
# Epoch 86/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0748 - acc: 0.9678 - val_loss: 0.2388 - val_acc: 0.9213
# Epoch 87/100
# 24/24 [==============================] - 33s 1s/step - loss: 0.0721 - acc: 0.9690 - val_loss: 0.2490 - val_acc: 0.9227
# Epoch 88/100
# 18/24 [=====================>........] - ETA: 7s - loss: 0.0720 - acc: 0.9691

# %%
# 降速训练1（0.0001）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.0001 / 5 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = EPOCHES
final_epochs = 20  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 101/120
# 20/20 [==============================] - 28s 1s/step - loss: 0.0838 - acc: 0.9634 - val_loss: 0.2307 - val_acc: 0.9246
# Epoch 102/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0790 - acc: 0.9659 - val_loss: 0.2334 - val_acc: 0.9242
# Epoch 103/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0781 - acc: 0.9663 - val_loss: 0.2343 - val_acc: 0.9242
# Epoch 104/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0772 - acc: 0.9667 - val_loss: 0.2342 - val_acc: 0.9243
# Epoch 105/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0775 - acc: 0.9667 - val_loss: 0.2345 - val_acc: 0.9242
# Epoch 106/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0768 - acc: 0.9669 - val_loss: 0.2345 - val_acc: 0.9241
# Epoch 107/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0764 - acc: 0.9670 - val_loss: 0.2346 - val_acc: 0.9240
# Epoch 108/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0761 - acc: 0.9672 - val_loss: 0.2343 - val_acc: 0.9240
# Epoch 109/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0756 - acc: 0.9674 - val_loss: 0.2342 - val_acc: 0.9241
# Epoch 110/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0763 - acc: 0.9671 - val_loss: 0.2341 - val_acc: 0.9242
# Epoch 111/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0749 - acc: 0.9677 - val_loss: 0.2348 - val_acc: 0.9242
# Epoch 112/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0753 - acc: 0.9676 - val_loss: 0.2350 - val_acc: 0.9242
# Epoch 113/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0752 - acc: 0.9676 - val_loss: 0.2346 - val_acc: 0.9243
# Epoch 114/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0753 - acc: 0.9675 - val_loss: 0.2350 - val_acc: 0.9241
# Epoch 115/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0744 - acc: 0.9679 - val_loss: 0.2355 - val_acc: 0.9241
# Epoch 116/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0750 - acc: 0.9676 - val_loss: 0.2363 - val_acc: 0.9240
# Epoch 117/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0740 - acc: 0.9681 - val_loss: 0.2357 - val_acc: 0.9244
# Epoch 118/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0739 - acc: 0.9681 - val_loss: 0.2371 - val_acc: 0.9241
# Epoch 119/120
# 20/20 [==============================] - 27s 1s/step - loss: 0.0740 - acc: 0.9681 - val_loss: 0.2372 - val_acc: 0.9242
# Epoch 120/120
# 20/20 [==============================] - 28s 1s/step - loss: 0.0744 - acc: 0.9680 - val_loss: 0.2366 - val_acc: 0.9242

# %%
model.save( 'model8_250_全网.h5' )

# %%
# 降速训练2（0.00001）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 121/170
# 20/20 [==============================] - 28s 1s/step - loss: 0.0733 - acc: 0.9683 - val_loss: 0.2380 - val_acc: 0.9240
# Epoch 122/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0740 - acc: 0.9681 - val_loss: 0.2379 - val_acc: 0.9240
# Epoch 123/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0741 - acc: 0.9681 - val_loss: 0.2376 - val_acc: 0.9241
# Epoch 124/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0736 - acc: 0.9683 - val_loss: 0.2377 - val_acc: 0.9241
# Epoch 125/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0743 - acc: 0.9680 - val_loss: 0.2374 - val_acc: 0.9242
# Epoch 126/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0732 - acc: 0.9685 - val_loss: 0.2380 - val_acc: 0.9241
# Epoch 127/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0730 - acc: 0.9686 - val_loss: 0.2378 - val_acc: 0.9240
# Epoch 128/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0730 - acc: 0.9685 - val_loss: 0.2384 - val_acc: 0.9240
# Epoch 129/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0731 - acc: 0.9686 - val_loss: 0.2388 - val_acc: 0.9240
# Epoch 130/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0736 - acc: 0.9683 - val_loss: 0.2391 - val_acc: 0.9239
# Epoch 131/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0735 - acc: 0.9683 - val_loss: 0.2389 - val_acc: 0.9240
# Epoch 132/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0737 - acc: 0.9683 - val_loss: 0.2387 - val_acc: 0.9240
# Epoch 133/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0730 - acc: 0.9686 - val_loss: 0.2390 - val_acc: 0.9240
# Epoch 134/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0731 - acc: 0.9685 - val_loss: 0.2393 - val_acc: 0.9241
# Epoch 135/170
# 20/20 [==============================] - 28s 1s/step - loss: 0.0729 - acc: 0.9686 - val_loss: 0.2393 - val_acc: 0.9241
# Epoch 136/170
# 20/20 [==============================] - 28s 1s/step - loss: 0.0731 - acc: 0.9685 - val_loss: 0.2390 - val_acc: 0.9241
# Epoch 137/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0730 - acc: 0.9685 - val_loss: 0.2396 - val_acc: 0.9240
# Epoch 138/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0727 - acc: 0.9687 - val_loss: 0.2397 - val_acc: 0.9239
# Epoch 139/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0728 - acc: 0.9687 - val_loss: 0.2393 - val_acc: 0.9240
# Epoch 140/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0727 - acc: 0.9687 - val_loss: 0.2396 - val_acc: 0.9239
# Epoch 141/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0722 - acc: 0.9689 - val_loss: 0.2400 - val_acc: 0.9240
# Epoch 142/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0724 - acc: 0.9687 - val_loss: 0.2408 - val_acc: 0.9239
# Epoch 143/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0726 - acc: 0.9688 - val_loss: 0.2401 - val_acc: 0.9239
# Epoch 144/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0730 - acc: 0.9686 - val_loss: 0.2401 - val_acc: 0.9239
# Epoch 145/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0722 - acc: 0.9689 - val_loss: 0.2401 - val_acc: 0.9239
# Epoch 146/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0724 - acc: 0.9688 - val_loss: 0.2400 - val_acc: 0.9240
# Epoch 147/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0726 - acc: 0.9687 - val_loss: 0.2400 - val_acc: 0.9240
# Epoch 148/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0723 - acc: 0.9688 - val_loss: 0.2401 - val_acc: 0.9240
# Epoch 149/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0721 - acc: 0.9690 - val_loss: 0.2404 - val_acc: 0.9241
# Epoch 150/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0721 - acc: 0.9690 - val_loss: 0.2405 - val_acc: 0.9240
# Epoch 151/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0723 - acc: 0.9689 - val_loss: 0.2410 - val_acc: 0.9241
# Epoch 152/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0726 - acc: 0.9687 - val_loss: 0.2413 - val_acc: 0.9240
# Epoch 153/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0719 - acc: 0.9690 - val_loss: 0.2411 - val_acc: 0.9241
# Epoch 154/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0723 - acc: 0.9689 - val_loss: 0.2415 - val_acc: 0.9241
# Epoch 155/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0718 - acc: 0.9691 - val_loss: 0.2418 - val_acc: 0.9240
# Epoch 156/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0713 - acc: 0.9692 - val_loss: 0.2418 - val_acc: 0.9241
# Epoch 157/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0717 - acc: 0.9691 - val_loss: 0.2419 - val_acc: 0.9242
# Epoch 158/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0722 - acc: 0.9689 - val_loss: 0.2415 - val_acc: 0.9240
# Epoch 159/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0715 - acc: 0.9692 - val_loss: 0.2417 - val_acc: 0.9241
# Epoch 160/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0722 - acc: 0.9689 - val_loss: 0.2427 - val_acc: 0.9240
# Epoch 161/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0721 - acc: 0.9690 - val_loss: 0.2415 - val_acc: 0.9241
# Epoch 162/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0716 - acc: 0.9692 - val_loss: 0.2415 - val_acc: 0.9241
# Epoch 163/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0715 - acc: 0.9692 - val_loss: 0.2422 - val_acc: 0.9240
# Epoch 164/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0720 - acc: 0.9690 - val_loss: 0.2421 - val_acc: 0.9241
# Epoch 165/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0714 - acc: 0.9692 - val_loss: 0.2423 - val_acc: 0.9240
# Epoch 166/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0718 - acc: 0.9691 - val_loss: 0.2416 - val_acc: 0.9241
# Epoch 167/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0712 - acc: 0.9694 - val_loss: 0.2423 - val_acc: 0.9240
# Epoch 168/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0711 - acc: 0.9694 - val_loss: 0.2425 - val_acc: 0.9240
# Epoch 169/170
# 20/20 [==============================] - 27s 1s/step - loss: 0.0717 - acc: 0.9691 - val_loss: 0.2425 - val_acc: 0.9240
# Epoch 170/170
# 11/20 [===============>..............] - ETA: 10s - loss: 0.0712 - acc: 0.9694

# %%
# 降速训练3（0.00001/5）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 / 5 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 251/300
# 8/8 [==============================] - 11s 1s/step - loss: 0.0615 - acc: 0.9741 - val_loss: 0.8119 - val_acc: 0.8425
# Epoch 252/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0613 - acc: 0.9742 - val_loss: 0.8120 - val_acc: 0.8425
# Epoch 253/300
# 8/8 [==============================] - 11s 1s/step - loss: 0.0625 - acc: 0.9736 - val_loss: 0.8123 - val_acc: 0.8425
# Epoch 254/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0630 - acc: 0.9734 - val_loss: 0.8124 - val_acc: 0.8425
# Epoch 255/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0635 - acc: 0.9733 - val_loss: 0.8125 - val_acc: 0.8425
# Epoch 256/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0641 - acc: 0.9729 - val_loss: 0.8128 - val_acc: 0.8423
# Epoch 257/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - acc: 0.9740 - val_loss: 0.8127 - val_acc: 0.8424
# Epoch 258/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0624 - acc: 0.9737 - val_loss: 0.8130 - val_acc: 0.8424
# Epoch 259/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9740 - val_loss: 0.8130 - val_acc: 0.8424
# Epoch 260/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0627 - acc: 0.9735 - val_loss: 0.8131 - val_acc: 0.8423
# Epoch 261/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9741 - val_loss: 0.8129 - val_acc: 0.8423
# Epoch 262/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0622 - acc: 0.9737 - val_loss: 0.8129 - val_acc: 0.8423
# Epoch 263/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0631 - acc: 0.9734 - val_loss: 0.8131 - val_acc: 0.8422
# Epoch 264/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0631 - acc: 0.9733 - val_loss: 0.8134 - val_acc: 0.8422
# Epoch 265/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9740 - val_loss: 0.8133 - val_acc: 0.8423
# Epoch 266/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0617 - acc: 0.9739 - val_loss: 0.8134 - val_acc: 0.8423
# Epoch 267/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0620 - acc: 0.9739 - val_loss: 0.8137 - val_acc: 0.8422
# Epoch 268/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9740 - val_loss: 0.8139 - val_acc: 0.8422
# Epoch 269/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0622 - acc: 0.9737 - val_loss: 0.8139 - val_acc: 0.8422
# Epoch 270/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.8141 - val_acc: 0.8422
# Epoch 271/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0639 - acc: 0.9730 - val_loss: 0.8139 - val_acc: 0.8422
# Epoch 272/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0640 - acc: 0.9730 - val_loss: 0.8140 - val_acc: 0.8421
# Epoch 273/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9737 - val_loss: 0.8138 - val_acc: 0.8421
# Epoch 274/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0619 - acc: 0.9738 - val_loss: 0.8140 - val_acc: 0.8421
# Epoch 275/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0611 - acc: 0.9743 - val_loss: 0.8140 - val_acc: 0.8422
# Epoch 276/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0613 - acc: 0.9742 - val_loss: 0.8140 - val_acc: 0.8422
# Epoch 277/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0620 - acc: 0.9739 - val_loss: 0.8139 - val_acc: 0.8422
# Epoch 278/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0619 - acc: 0.9739 - val_loss: 0.8141 - val_acc: 0.8421
# Epoch 279/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0618 - acc: 0.9739 - val_loss: 0.8143 - val_acc: 0.8421
# Epoch 280/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - acc: 0.9741 - val_loss: 0.8145 - val_acc: 0.8420
# Epoch 281/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0622 - acc: 0.9737 - val_loss: 0.8145 - val_acc: 0.8421
# Epoch 282/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0624 - acc: 0.9736 - val_loss: 0.8147 - val_acc: 0.8421
# Epoch 283/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0634 - acc: 0.9732 - val_loss: 0.8146 - val_acc: 0.8421
# Epoch 284/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0612 - acc: 0.9743 - val_loss: 0.8145 - val_acc: 0.8422
# Epoch 285/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9737 - val_loss: 0.8144 - val_acc: 0.8421
# Epoch 286/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0612 - acc: 0.9742 - val_loss: 0.8146 - val_acc: 0.8421
# Epoch 287/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0626 - acc: 0.9736 - val_loss: 0.8143 - val_acc: 0.8421
# Epoch 288/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0627 - acc: 0.9735 - val_loss: 0.8145 - val_acc: 0.8421
# Epoch 289/300
# 8/8 [==============================] - 11s 1s/step - loss: 0.0619 - acc: 0.9739 - val_loss: 0.8144 - val_acc: 0.8421
# Epoch 290/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0628 - acc: 0.9735 - val_loss: 0.8147 - val_acc: 0.8421
# Epoch 291/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0636 - acc: 0.9732 - val_loss: 0.8147 - val_acc: 0.8422
# Epoch 292/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9741 - val_loss: 0.8147 - val_acc: 0.8422
# Epoch 293/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0630 - acc: 0.9734 - val_loss: 0.8149 - val_acc: 0.8421
# Epoch 294/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - acc: 0.9740 - val_loss: 0.8150 - val_acc: 0.8421
# Epoch 295/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - acc: 0.9741 - val_loss: 0.8151 - val_acc: 0.8420
# Epoch 296/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0630 - acc: 0.9734 - val_loss: 0.8152 - val_acc: 0.8420
# Epoch 297/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - acc: 0.9742 - val_loss: 0.8153 - val_acc: 0.8420
# Epoch 298/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0649 - acc: 0.9727 - val_loss: 0.8154 - val_acc: 0.8419
# Epoch 299/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0644 - acc: 0.9730 - val_loss: 0.8151 - val_acc: 0.8420
# Epoch 300/300
# 8/8 [==============================] - 10s 1s/step - loss: 0.0607 - acc: 0.9744 - val_loss: 0.8150 - val_acc: 0.8420

# %%
# 降速训练4（0.00001/10）：再次编译 + 再次训练
model.compile(
    optimizer = tf.keras.optimizers.Adam( lr = 0.00001 / 10 ),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['acc']
)

# 再次训练：
initial_epochs = total_epochs
final_epochs = 50  # 再多训练10个epoch
total_epochs = initial_epochs + final_epochs

history = model.fit(
    train_dataset,
    epochs = total_epochs,
    initial_epoch = initial_epochs,  # 数值从initial_epochs开始记录而已！
    steps_per_epoch = train_count // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = val_count // BATCH_SIZE,
    # 回调函数：
    callbacks = [cp_callback]
)
# Out:
# Epoch 301/350
# 8/8 [==============================] - 11s 1s/step - loss: 0.0616 - acc: 0.9740 - val_loss: 0.8149 - val_acc: 0.8421
# Epoch 302/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - acc: 0.9741 - val_loss: 0.8150 - val_acc: 0.8421
# Epoch 303/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0620 - acc: 0.9739 - val_loss: 0.8149 - val_acc: 0.8421
# Epoch 304/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - acc: 0.9740 - val_loss: 0.8148 - val_acc: 0.8421
# Epoch 305/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0626 - acc: 0.9735 - val_loss: 0.8148 - val_acc: 0.8421
# Epoch 306/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0646 - acc: 0.9727 - val_loss: 0.8151 - val_acc: 0.8420
# Epoch 307/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0612 - acc: 0.9742 - val_loss: 0.8150 - val_acc: 0.8421
# Epoch 308/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.8151 - val_acc: 0.8421
# Epoch 309/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0611 - acc: 0.9742 - val_loss: 0.8150 - val_acc: 0.8421
# Epoch 310/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0631 - acc: 0.9735 - val_loss: 0.8152 - val_acc: 0.8421
# Epoch 311/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9737 - val_loss: 0.8152 - val_acc: 0.8421
# Epoch 312/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0629 - acc: 0.9735 - val_loss: 0.8153 - val_acc: 0.8421
# Epoch 313/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0617 - acc: 0.9740 - val_loss: 0.8153 - val_acc: 0.8421
# Epoch 314/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - acc: 0.9741 - val_loss: 0.8152 - val_acc: 0.8420
# Epoch 315/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0638 - acc: 0.9731 - val_loss: 0.8154 - val_acc: 0.8419
# Epoch 316/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0615 - acc: 0.9740 - val_loss: 0.8152 - val_acc: 0.8420
# Epoch 317/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0627 - acc: 0.9736 - val_loss: 0.8149 - val_acc: 0.8421
# Epoch 318/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0610 - acc: 0.9742 - val_loss: 0.8149 - val_acc: 0.8421
# Epoch 319/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0624 - acc: 0.9736 - val_loss: 0.8150 - val_acc: 0.8420
# Epoch 320/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0611 - acc: 0.9742 - val_loss: 0.8150 - val_acc: 0.8421
# Epoch 321/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9738 - val_loss: 0.8152 - val_acc: 0.8420
# Epoch 322/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0613 - acc: 0.9741 - val_loss: 0.8150 - val_acc: 0.8420
# Epoch 323/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.8152 - val_acc: 0.8420
# Epoch 324/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0632 - acc: 0.9733 - val_loss: 0.8153 - val_acc: 0.8420
# Epoch 325/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - acc: 0.9740 - val_loss: 0.8154 - val_acc: 0.8420
# Epoch 326/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9739 - val_loss: 0.8153 - val_acc: 0.8419
# Epoch 327/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0603 - acc: 0.9745 - val_loss: 0.8154 - val_acc: 0.8419
# Epoch 328/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9737 - val_loss: 0.8155 - val_acc: 0.8419
# Epoch 329/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0608 - acc: 0.9743 - val_loss: 0.8154 - val_acc: 0.8420
# Epoch 330/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0610 - acc: 0.9743 - val_loss: 0.8153 - val_acc: 0.8420
# Epoch 331/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0606 - acc: 0.9745 - val_loss: 0.8154 - val_acc: 0.8420
# Epoch 332/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.8156 - val_acc: 0.8420
# Epoch 333/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0605 - acc: 0.9745 - val_loss: 0.8156 - val_acc: 0.8420
# Epoch 334/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0621 - acc: 0.9738 - val_loss: 0.8158 - val_acc: 0.8420
# Epoch 335/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0629 - acc: 0.9735 - val_loss: 0.8159 - val_acc: 0.8419
# Epoch 336/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0664 - acc: 0.9726 - val_loss: 0.8155 - val_acc: 0.8420
# Epoch 337/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9737 - val_loss: 0.8157 - val_acc: 0.8420
# Epoch 338/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0610 - acc: 0.9743 - val_loss: 0.8157 - val_acc: 0.8419
# Epoch 339/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0617 - acc: 0.9740 - val_loss: 0.8156 - val_acc: 0.8420
# Epoch 340/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - acc: 0.9741 - val_loss: 0.8158 - val_acc: 0.8420
# Epoch 341/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0627 - acc: 0.9737 - val_loss: 0.8159 - val_acc: 0.8420
# Epoch 342/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0612 - acc: 0.9742 - val_loss: 0.8158 - val_acc: 0.8420
# Epoch 343/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0613 - acc: 0.9742 - val_loss: 0.8160 - val_acc: 0.8420
# Epoch 344/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0599 - acc: 0.9747 - val_loss: 0.8161 - val_acc: 0.8420
# Epoch 345/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0623 - acc: 0.9736 - val_loss: 0.8161 - val_acc: 0.8420
# Epoch 346/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0634 - acc: 0.9733 - val_loss: 0.8160 - val_acc: 0.8420
# Epoch 347/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0630 - acc: 0.9734 - val_loss: 0.8161 - val_acc: 0.8420
# Epoch 348/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0608 - acc: 0.9743 - val_loss: 0.8160 - val_acc: 0.8421
# Epoch 349/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0612 - acc: 0.9742 - val_loss: 0.8159 - val_acc: 0.8421
# Epoch 350/350
# 8/8 [==============================] - 10s 1s/step - loss: 0.0628 - acc: 0.9735 - val_loss: 0.8159 - val_acc: 0.8420

# %%
# 备用模型保存函数 + 导入：保存当前模型 —— 临时保存在当前目录下。
model.save( 'model4_100_调过拟合.h5' )
new_model = tf.keras.models.load_model( 'model4_100_调过拟合.h5' )

# %% [markdown]
# ### 5. 查看效果：

# %%
# 模型加载：因为保存的是全体模型，所以直接直接导入即可（和导入.h5文件方式一样！）
# new_model = tf.keras.models.load_model( '/home/gaoboyu/学习保存的模型/沙漠4' )  # 括号里写model的地址

# %%
# 在训练数据上看效果：
num = 10 # 一次看5张效果！

for image, label_real in train_dataset.take(1):
    label_pred = new_model.predict(image)
    label_pred = tf.argmax( label_pred, axis = -1 )  # 每个维度上，取一个最大值！
    
    plt.figure( figsize=(20,20) )
    # 每行3张图，从左到右：原图、真实标签图、预测标签图
    for i in range(num):
        plt.subplot(num, 3, i*3 + 1)
        plt.imshow( (image[i].numpy() + 1)/2 )
        plt.subplot(num, 3, i*3 + 2)
        plt.imshow( label_real[i].numpy().reshape(256,256) )
        plt.subplot(num, 3, i*3 + 3)
        plt.imshow( label_pred[i].numpy().reshape(256,256) )

# %%
# 在训练数据上看效果：
num = 10 # 一次看10张效果！

for image, label_real in val_dataset.take(1):
    label_pred = new_model.predict(image)
    label_pred = tf.argmax( label_pred, axis = -1 )  # 每个维度上，取一个最大值！
    
    plt.figure( figsize=(20,20) )
    # 每行3张图，从左到右：原图、真实标签图、预测标签图
    for i in range(num):
        plt.subplot(num, 3, i*3 + 1)
        plt.imshow( (image[i].numpy() + 1)/2 )
        plt.subplot(num, 3, i*3 + 2)
        plt.imshow( label_real[i].numpy().reshape(256,256) )
        plt.subplot(num, 3, i*3 + 3)
        plt.imshow( label_pred[i].numpy().reshape(256,256) )

# %%
# 用当前模型测试一张图：
img_test = glob.glob( r'/home/gaoboyu/学习数据集/沙漠数据集3/subimg_172.png' )

img_test = read_image(img_test[0])
img_test = tf.expand_dims( img_test, axis = 0 )

label_pred = new_model.predict(img_test)
label_pred = tf.argmax( label_pred, axis = -1 )  # 每个维度上，取一个最大值！

img_test = tf.squeeze( img_test, axis = 0 )

plt.figure( figsize=(10,10) )
plt.subplot(1, 2, 1)
plt.imshow( img_test.numpy() )
plt.subplot(1, 2, 2)
plt.imshow( label_pred[0].numpy().reshape(256,256) )
